# %% [markdown]
# # Kaggle dataset 분석
# 이 파일은 Every Cryptocurrency Daily Market Price의 데이터셋을 분석, 시각화를 위한 문서입니다.

# %% [markdown]
# ## Dataset 기본 정보
# - slug: 표기 이름
# - symbol: 표기 약칭
# - name: 정식 이름
# - date: 거래일자
# - rank: 마켓 순위 (Volume기준)
# - open: 시작 가격
# - high: 당일 최고가
# - low: 당일 최저가
# - close: 마감 가격
# - volume: 거래량
# - market: 마켓 내 총 수량
# - close_ratio: 당일 마감 비율
#     - (close - low) / (high - low)
# - spread: 당일 최고가와 최저가의 차이

# %%
# Load dataset
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from datetime import datetime, timedelta

import matplotlib.dates as mdates
from mpl_finance import candlestick_ohlc

# Default number of currencies we will look at each step
x = 10

# %%
df = pd.read_csv('data/crypto-markets.csv')

df.head()
# Out:
#       slug symbol     name        date  ranknow    open    high     low  \
# 0  bitcoin    BTC  Bitcoin  2013-04-28        1  135.30  135.98  132.10
# 1  bitcoin    BTC  Bitcoin  2013-04-29        1  134.44  147.49  134.00
# 2  bitcoin    BTC  Bitcoin  2013-04-30        1  144.00  146.93  134.05
# 3  bitcoin    BTC  Bitcoin  2013-05-01        1  139.00  139.89  107.72
# 4  bitcoin    BTC  Bitcoin  2013-05-02        1  116.38  125.60   92.28
#
#     close  volume        market  close_ratio  spread
# 0  134.21     0.0  1.500520e+09       0.5438    3.88
# 1  144.54     0.0  1.491160e+09       0.7813   13.49
# 2  139.00     0.0  1.597780e+09       0.3843   12.88
# 3  116.99     0.0  1.542820e+09       0.2882   32.17
# 4  105.21     0.0  1.292190e+09       0.3881   33.32

# %%
# Transform date to date object
df['date'] = pd.to_datetime(df['date'], format='%Y-%m-%d')

# %%
# Get a df containing only the latest date's data for each currency
print("Latest crypto data")
latest_df = df[df['date'] == max(df['date'])]
latest_df.head()
# Out:
# Latest crypto data
#               slug symbol          name       date  ranknow         open  \
# 1865       bitcoin    BTC       Bitcoin 2018-06-06        1  7625.970000
# 2900      ethereum    ETH      Ethereum 2018-06-06        2   610.260000
# 4668        ripple    XRP        Ripple 2018-06-06        3     0.677901
# 4987  bitcoin-cash    BCH  Bitcoin Cash 2018-06-06        4  1157.330000
# 5328           eos    EOS           EOS 2018-06-06        5    14.250000
#
#              high          low        close        volume        market  \
# 1865  7680.430000  7502.010000  7653.980000  4.692260e+09  1.302330e+11
# 2900   611.640000   596.400000   607.120000  1.756530e+09  6.096070e+10
# 4668     0.681668     0.660059     0.674797  2.739660e+08  2.660190e+10
# 4987  1157.330000  1107.210000  1131.170000  6.085030e+08  1.986880e+10
# 5328    14.260000    13.480000    13.940000  1.022290e+09  1.277380e+10
#
#       close_ratio  spread
# 1865       0.8518  178.42
# 2900       0.7034   15.24
# 4668       0.6820    0.02
# 4987       0.4781   50.12
# 5328       0.5897    0.78

# %%
# Number of cryptocurrencies listed
#latest_df.shape
print("Number of cryptocurrencies listed")
latest_df['symbol'].nunique()
# Out:
# Number of cryptocurrencies listed
# 1555

# %% [markdown]
# ## Oldest and newest Cryptocurrencies

# %%
# What start date do we have for each cryptocurrency?
start_df = pd.DataFrame({'start_date' : df.groupby( [ "name", "ranknow"] )['date'].min()}).reset_index()

# List the oldest ones
print("Oldest Cryptocurrencies")
start_df.sort_values(['start_date']).head(x)
# Out:
# Oldest Cryptocurrencies
#              name  ranknow start_date
# 1421    Terracoin      763 2013-04-28
# 1015     Novacoin      549 2013-04-28
# 1094     Peercoin      208 2013-04-28
# 864      Litecoin        6 2013-04-28
# 983      Namecoin      310 2013-04-28
# 173       Bitcoin        1 2013-04-28
# 932       Mincoin     1243 2013-05-03
# 587   Feathercoin      321 2013-05-03
# 611      Freicoin     1171 2013-05-03
# 791        Ixcoin     1051 2013-05-08

# %%
# List the newest ones
print("Newest Cryptocurrencies")
start_df.sort_values(['start_date']).tail(x)
# Out:
# Newest Cryptocurrencies
#             name  ranknow start_date
# 1      0xBitcoin     1420 2018-06-04
# 141       Bigbom      642 2018-06-04
# 1063      PCHAIN     1378 2018-06-04
# 1177  QuarkChain     1365 2018-06-04
# 1299      Shopin     1471 2018-06-04
# 364     Cryptaur     1463 2018-06-05
# 120      Bankera     1385 2018-06-05
# 876    LoyalCoin      266 2018-06-05
# 542   Ether Zero     1436 2018-06-05
# 886         MEDX     1424 2018-06-06

# %% [markdown]
# ## Ranking

# %%
# Get a list of the top x currencies
latest_df[latest_df['ranknow'] <= x].groupby('ranknow').name.unique()
# Out:
# ranknow
# 1          [Bitcoin]
# 2         [Ethereum]
# 3           [Ripple]
# 4     [Bitcoin Cash]
# 5              [EOS]
# 6         [Litecoin]
# 7          [Stellar]
# 8          [Cardano]
# 9             [IOTA]
# 10            [TRON]
# Name: name, dtype: object

# %%
# Is ranknow ordering the same as the marketcap ordering?
latest_df.sort_values(by=['market'], ascending=[False])
latest_df[['name','market']].head(x)

# Answer: Yes
# Out:
#               name        market
# 1865       Bitcoin  1.302330e+11
# 2900      Ethereum  6.096070e+10
# 4668        Ripple  2.660190e+10
# 4987  Bitcoin Cash  1.986880e+10
# 5328           EOS  1.277380e+10
# 7194      Litecoin  6.929530e+09
# 8596       Stellar  5.450080e+09
# 8845       Cardano  5.718610e+09
# 9204          IOTA  4.863620e+09
# 9471          TRON  3.985740e+09

# %% [markdown]
# ## Market Value
# Market capitalization이라고도 불립니다. 이 수치는 현재 Market 규모 * cryptocurrency의 현재 가격으로 산출합니다. 이 방법은 cryptocurrency의 relative size를 비교할 수 있습니다.

# %%
# Plot the top X currencies latest marketval
name = latest_df['name'].unique()
currency  = []
marketval = []
x_currencies = name[:x]
for i, cn in enumerate(x_currencies):
     filtered = latest_df[(latest_df['name']==str(cn))]
     currency.append(str(cn))
     marketval.append(filtered['market'].values[0])

f, ax = plt.subplots(figsize=(20, 8)) 
g = sns.barplot( y = currency, x = marketval, palette=sns.cubehelix_palette(x, reverse=True))
plt.title("Top X Cryptocurrencies Marketval")
ax.set_xticklabels(ax.get_xticks())
fig=plt.gcf()
plt.show()

# %% [markdown]
# # Volume
# 특정 기간 내의 cryptocurrency의 거래량을 확인합니다. 거래 데이터에서 사용할 수 있는 간단하고도 강력한 지표입니다.

# %%
# Plot the top X currencies "latest" volume 
latest_df
currency  = []
volume = []
x_currencies = name[:x]
for i, cn in enumerate(x_currencies):
     filtered = latest_df[(latest_df['name']==str(cn))]
     currency.append(str(cn))
     volume.append(filtered['volume'].values[0])
        
f, ax = plt.subplots(figsize=(20, 8)) 
g = sns.barplot( y = currency, x = volume, palette=sns.cubehelix_palette(x, reverse=True))
plt.title("Top X Cryptocurrencies Volume")
ax.set_xticklabels(ax.get_xticks())
fig=plt.gcf()
plt.show()

# %% [markdown]
# ## Candlestick Chart
# 일명 '봉 차트'라고도 불립니다. 해당 cryptocurrency의 가격의 변동을 알수 있습니다.
# <br> 여기서 초록색(또는 파란색)막대는 양봉('strength'), 그리고 붉은색 막대는 음봉('weakness')라고 불립니다.
# <br> 이 막대 중앙에서 나오는 긴 선은 'tails' 또는 'wicks'라고 불리며 최저/최고가를 기준으로 생성됩니다.
# <br> 이 막대를 이루고 있는 바는 해당 일의 마켓 시작/종료 가격을 기준으로 생성됩니다.

# %%
# Candlestick chart for Rank 1 currency (limited to 6 Months)
rank = 1    # Indicates 'Bitcoin'
months = 6

name = df[df.ranknow == rank].iloc[-1]['name']
filtered_df = df[(df['ranknow'] == rank) & (df['date'] > (max(df['date']) - timedelta(days=30*months)))]
OHLCfiltered_df = filtered_df[['date','open','high','low','close']]
OHLCfiltered_df['date'] = mdates.date2num(OHLCfiltered_df['date'].dt.date)

f,ax=plt.subplots(figsize=(15,11))
ax.xaxis_date()
candlestick_ohlc(ax, OHLCfiltered_df.values, width=0.5, colorup='g', colordown='r',alpha=0.75)

plt.xlabel("Date")
ax.xaxis.set_major_formatter(mdates.DateFormatter('%Y-%m-%d'))
plt.gcf().autofmt_xdate()
plt.title(name + " price")
plt.ylabel("Price")
plt.show()
# Out:
# C:\Users\jungw\Anaconda3\lib\site-packages\ipykernel_launcher.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy

# %%
# Candlestick chart for Rank 2 currency (limited to 6 Months)
rank = 2    # Indicates 'Ethereum'
months = 6

name = df[df.ranknow == rank].iloc[-1]['name']
filtered_df = df[(df['ranknow'] == rank) & (df['date'] > (max(df['date']) - timedelta(days=30*months)))]
OHLCfiltered_df = filtered_df[['date','open','high','low','close']]
OHLCfiltered_df['date'] = mdates.date2num(OHLCfiltered_df['date'].dt.date)

f,ax=plt.subplots(figsize=(15,11))
ax.xaxis_date()
candlestick_ohlc(ax, OHLCfiltered_df.values, width=0.5, colorup='g', colordown='r',alpha=0.75)

plt.xlabel("Date")
ax.xaxis.set_major_formatter(mdates.DateFormatter('%Y-%m-%d'))
plt.gcf().autofmt_xdate()
plt.title(name + " price")
plt.ylabel("Price")
plt.show()
# Out:
# C:\Users\jungw\Anaconda3\lib\site-packages\ipykernel_launcher.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy

# %% [markdown]
# ## Moving averages (이동평균)
# 이동평균은 특정 지표의 '트렌드(경향)'을 찾는데 용이하게 쓰여왔던 방법입니다.
# <br>이 방법은 가장 간단한 방법 중 하나이면서도 가장 오랫동안 쓰여왔던 방법중 하나이기도 합니다.
# <br>예를 들면 n일동안의 이동평균을 계산한다고 하면, 해당일로부터 n일 전까지의 평균가격을 산출합니다.
# <br>이 n값이 작을수록 단기적인 경향을 보여주기 쉽고, 반대로 n값이 크다면 장기적인 경향을 보여주기 쉽습니다.
# <br>이와 같은 방법은 해당 기간 내의 "노이즈"에 상대적으로 강한 경향 분석에 용이하다는 장점이 있습니다.
# <br>Exponentially Weighted Moving Average(지수이동평균, EWMA)는 기준일로부터 멀리있는 날의 가격은 비중이 낮게,
# <br>가까이 있는 날의 가격은 비중이 높게 계산하는 방법입니다. (이 경우, n은 __사용하지 않습니다.__)

# %%
# Moving average chart for Rank 1 currency (6 months)
rank = 1
months = 6
name = df[df.ranknow == rank].iloc[-1]['name']
filtered_df = df[(df['ranknow'] == rank) & (df['date'] > (max(df['date']) - timedelta(days=30*months)))]

filtered_df.set_index('date', inplace=True)

f, ax = plt.subplots(figsize=(15,11))
filtered_df.close.plot(label='Raw', ax=ax)
filtered_df.close.rolling(20).mean().plot(label='20D MA', ax=ax)
filtered_df.close.ewm(alpha=0.03).mean().plot(label='EWMA($\\alpha=.03$)', ax=ax)

plt.title(name + " price with Moving Averages")
plt.legend()
plt.xlabel("Date")
plt.gcf().autofmt_xdate()
plt.ylabel("Close ($)")
plt.show()

# %%
# Moving average chart for Rank 2 currency (6 months)
rank = 2
months = 6
name = df[df.ranknow == rank].iloc[-1]['name']
filtered_df = df[(df['ranknow'] == rank) & (df['date'] > (max(df['date']) - timedelta(days=30*months)))]

filtered_df.set_index('date', inplace=True)

f, ax = plt.subplots(figsize=(15,11))
filtered_df.close.plot(label='Raw', ax=ax)
filtered_df.close.rolling(20).mean().plot(label='20D MA', ax=ax)
filtered_df.close.ewm(alpha=0.03).mean().plot(label='EWMA($\\alpha=.03$)', ax=ax)

plt.title(name + " price with Moving Averages")
plt.legend()
plt.xlabel("Date")
plt.gcf().autofmt_xdate()
plt.ylabel("Close ($)")
plt.show()

# %% [markdown]
# 여기서 n값이 얼마인가에 따라 이동평균(moving average)가 나타내고자 하는 목표가 달라집니다.
# - n=20 : 단기간의 트렌드 분석
# - n=50 : 중간(medium) 기간의 트렌드 분석
# - n=200 : 장기적인 트렌드 분석
#
# 여기서 상승세라면 20MA가 제일 위, 20MA아래로 50MA, 그리고 50MA아래로 200MA 그래프가 나타날 것 입니다.
# <br>반대로 하락세라면 20MA가 가장 아래, 20MA 위로 50MA, 그리고 50MA 위로 200MA 그래프가 나타날 것 입니다.
# <br>
# <br>이 원리를 Bitcoin과 Ethereum의 가격 변동 그래프를 통해서 살펴보겠습니다.

# %%
# Moving average chart for Rank 1 currency (10 months)
rank = 1
months = 10
name = df[df.ranknow == rank].iloc[-1]['name']
filtered_df = df[(df['ranknow'] == rank) & (df['date'] > (max(df['date']) - timedelta(days=30*months)))]

filtered_df.set_index('date', inplace=True)

# simple moving averages
sma20 = filtered_df.close.rolling(20).mean()
sma50 = filtered_df.close.rolling(50).mean()
sma200 = filtered_df.close.rolling(200).mean()
 
smaplot = pd.DataFrame({'Raw': filtered_df.close, 'SMA 20': sma20, 'SMA 50': sma50, 'SMA 200': sma200})
smaplot.plot(figsize=(15, 11), legend=True, title=name + " price with Moving Averages")

plt.gcf().autofmt_xdate()
plt.show()

# %%
# Moving average chart for Rank 2 currency (10 months)
rank = 2
months = 10
name = df[df.ranknow == rank].iloc[-1]['name']
filtered_df = df[(df['ranknow'] == rank) & (df['date'] > (max(df['date']) - timedelta(days=30*months)))]

filtered_df.set_index('date', inplace=True)

# simple moving averages
sma20 = filtered_df.close.rolling(20).mean()
sma50 = filtered_df.close.rolling(50).mean()
sma200 = filtered_df.close.rolling(200).mean()
 
smaplot = pd.DataFrame({'Raw': filtered_df.close, 'SMA 20': sma20, 'SMA 50': sma50, 'SMA 200': sma200})
smaplot.plot(figsize=(15, 11), legend=True, title=name + " price with Moving Averages")

plt.gcf().autofmt_xdate()
plt.show()
